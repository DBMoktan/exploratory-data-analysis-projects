# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')
# %matplotlib inline

# %%
df = pd.read_csv('tracks.csv')

# %%
print("Top five rows:")
print(df.head(10))
# Out:
# Top five rows:
#                        id                                 name  popularity  \
# 0  35iwgR4jXetI318WEWsa1Q                                Carve           6
# 1  021ht4sdgPcrDgSk7JTbKY  Capítulo 2.16 - Banquero Anarquista           0
# 2  07A5yehtSnoedViJAZkNnc   Vivo para Quererte - Remasterizado           0
# 3  08FmqUhxtyLTn6pAh6bk45        El Prisionero - Remasterizado           0
# 4  08y9GfoqCWfOGsKdwojr5e                  Lady of the Evening           0
# 5  0BRXJHRNGQ3W4v9frnSfhu                            Ave Maria           0
# 6  0Dd9ImXtAtGwsmsAD69KZT                       La Butte Rouge           0
# 7  0IA0Hju8CAgYfV1hwhidBH                              La Java           0
# 8  0IgI1UCz84pYeVetnl1lGP                   Old Fashioned Girl           0
# 9  0JV4iqw2lSKJaHBQZ0e5zK        Martín Fierro - Remasterizado           0
#
#    duration_ms  explicit              artists                  id_artists  \
# ...

# %%
print("Bottom five rows:")
print(df.tail(5))
# Out:
# Bottom five rows:
#                             id                       name  popularity  \
# 586667  5rgu12WBIHQtvej2MdHSH0                        云与海          50
# 586668  0NuWgxEp51CutD2pJoF4OM                      blind          72
# 586669  27Y1N4Q4U3EfDU5Ubw8ws2  What They'll Say About Us          70
# 586670  45XJsGpFTyzbzeWK8VzR8S            A Day At A Time          58
# 586671  5Ocn6dZ3BJFPWh4ylwFXtn           Mar de Emociones          38
#
#         duration_ms  explicit                          artists  \
# 586667       258267         0                      ['阿YueYue']
# 586668       153293         0                   ['ROLE MODEL']
# 586669       187601         0                      ['FINNEAS']
# 586670       142003         0  ['Gentle Bones', 'Clara Benin']
# 586671       214360         0                    ['Afrosound']
#
#                                                id_artists release_date  \
# ...

# %%
df.shape
# Out:
# (586672, 20)

# %%
df.columns
# Out:
# Index(['id', 'name', 'popularity', 'duration_ms', 'explicit', 'artists',
#        'id_artists', 'release_date', 'danceability', 'energy', 'key',
#        'loudness', 'mode', 'speechiness', 'acousticness', 'instrumentalness',
#        'liveness', 'valence', 'tempo', 'time_signature'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 586672 entries, 0 to 586671
# Data columns (total 20 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   id                586672 non-null  object
#  1   name              586601 non-null  object
#  2   popularity        586672 non-null  int64
#  3   duration_ms       586672 non-null  int64
#  4   explicit          586672 non-null  int64
#  5   artists           586672 non-null  object
#  6   id_artists        586672 non-null  object
#  7   release_date      586672 non-null  object
#  8   danceability      586672 non-null  float64
#  9   energy            586672 non-null  float64
#  10  key               586672 non-null  int64
#  11  loudness          586672 non-null  float64
#  12  mode              586672 non-null  int64
#  13  speechiness       586672 non-null  float64
#  14  acousticness      586672 non-null  float64
#  15  instrumentalness  586672 non-null  float64
# ...

# %%
df.describe()
# Out:
#           popularity   duration_ms       explicit   danceability  \
# count  586672.000000  5.866720e+05  586672.000000  586672.000000
# mean       27.570053  2.300512e+05       0.044086       0.563594
# std        18.370642  1.265261e+05       0.205286       0.166103
# min         0.000000  3.344000e+03       0.000000       0.000000
# 25%        13.000000  1.750930e+05       0.000000       0.453000
# 50%        27.000000  2.148930e+05       0.000000       0.577000
# 75%        41.000000  2.638670e+05       0.000000       0.686000
# max       100.000000  5.621218e+06       1.000000       0.991000
#
#               energy            key       loudness           mode  \
# count  586672.000000  586672.000000  586672.000000  586672.000000
# mean        0.542036       5.221603     -10.206067       0.658797
# std         0.251923       3.519423       5.089328       0.474114
# min         0.000000       0.000000     -60.000000       0.000000
# ...

# %%
df.describe(include=object)
# Out:
#                             id        name           artists  \
# count                   586672      586601            586672
# unique                  586672      446474            114030
# top     2nt8dbNspSCB9p7YgLIblV  Summertime  ['Die drei ???']
# freq                         1         101              3856
#
#                         id_artists release_date
# count                       586672       586672
# unique                      115062        19700
# top     ['3meJIgRw7YleJrmbpbJK6S']   1998-01-01
# freq                          3856         2893

# %%
df.describe(include=int)
# Out:
#           popularity   duration_ms       explicit            key  \
# count  586672.000000  5.866720e+05  586672.000000  586672.000000
# mean       27.570053  2.300512e+05       0.044086       5.221603
# std        18.370642  1.265261e+05       0.205286       3.519423
# min         0.000000  3.344000e+03       0.000000       0.000000
# 25%        13.000000  1.750930e+05       0.000000       2.000000
# 50%        27.000000  2.148930e+05       0.000000       5.000000
# 75%        41.000000  2.638670e+05       0.000000       8.000000
# max       100.000000  5.621218e+06       1.000000      11.000000
#
#                 mode  time_signature
# count  586672.000000   586672.000000
# mean        0.658797        3.873382
# std         0.474114        0.473162
# min         0.000000        0.000000
# 25%         0.000000        4.000000
# 50%         1.000000        4.000000
# 75%         1.000000        4.000000
# max         1.000000        5.000000

# %%
df.describe(include=float)
# Out:
#         danceability         energy       loudness    speechiness  \
# count  586672.000000  586672.000000  586672.000000  586672.000000
# mean        0.563594       0.542036     -10.206067       0.104864
# std         0.166103       0.251923       5.089328       0.179893
# min         0.000000       0.000000     -60.000000       0.000000
# 25%         0.453000       0.343000     -12.891000       0.034000
# 50%         0.577000       0.549000      -9.243000       0.044300
# 75%         0.686000       0.748000      -6.482000       0.076300
# max         0.991000       1.000000       5.376000       0.971000
#
#         acousticness  instrumentalness       liveness        valence  \
# count  586672.000000     586672.000000  586672.000000  586672.000000
# mean        0.449863          0.113451       0.213935       0.552292
# std         0.348837          0.266868       0.184326       0.257671
# min         0.000000          0.000000       0.000000       0.000000
# ...

# %%
df.describe().transpose()
# Out:
#                      count           mean            std     min          25%  \
# popularity        586672.0      27.570053      18.370642     0.0      13.0000
# duration_ms       586672.0  230051.167286  126526.087418  3344.0  175093.0000
# explicit          586672.0       0.044086       0.205286     0.0       0.0000
# danceability      586672.0       0.563594       0.166103     0.0       0.4530
# energy            586672.0       0.542036       0.251923     0.0       0.3430
# key               586672.0       5.221603       3.519423     0.0       2.0000
# loudness          586672.0     -10.206067       5.089328   -60.0     -12.8910
# mode              586672.0       0.658797       0.474114     0.0       0.0000
# speechiness       586672.0       0.104864       0.179893     0.0       0.0340
# acousticness      586672.0       0.449863       0.348837     0.0       0.0969
# instrumentalness  586672.0       0.113451       0.266868     0.0       0.0000
# ...

# %%
pd.isnull(df).sum()
#df.isnull().sum()
# Out:
# id                   0
# name                71
# popularity           0
# duration_ms          0
# explicit             0
# artists              0
# id_artists           0
# release_date         0
# danceability         0
# energy               0
# key                  0
# loudness             0
# mode                 0
# speechiness          0
# acousticness         0
# instrumentalness     0
# liveness             0
# valence              0
# tempo                0
# time_signature       0
# dtype: int64

# %%
# List of 10 least popular songs
least = df.sort_values('popularity', ascending = True)
least.head(10)
# Out:
#                             id                                name  \
# 135236  0V42QKc5fwqR129hetizY8                      My Wubba Dolly
# 135230  0LZWgBdX6wZ688csua4cGb         In The Royal Hawaiian Hotel
# 135229  0L4E8UrrII0WlvWQBScxqG                      Am I Dreaming?
# 135228  0L3jiDNbnzyPo39kUaJZ3C                   Movin' the boogie
# 135227  0GbAdJAfViur7mZKGipr5u                          Alibi Baby
# 135226  0GXbqxO4icMzj7tUqjfGbu      If somebody would only love me
# 135225  0FgFq4tTHEtbLGxDol7AkF  If the Man In the Moon Were a Coon
# 135224  0CzVyqzwgzL7UFW8uvfMIg         It All Comes Back to Me Now
# 135223  0C7wjpM0XgwplYgo8c834t                         Hyena stomp
# 135222  0BL93JqzRuz3CyJYroulFh  Now You've Got Me Worryin' for You
#
#         popularity  duration_ms  explicit  \
# 135236           0       167826         0
# 135230           0       158746         0
# 135229           0       150409         0
# 135228           0       160994         0
# ...

# %%
# Songs with popularity score greater than 90
popular = df.query('popularity > 0', inplace = False).sort_values('popularity', ascending = False)
popular.head(10)
# Out:
#                            id                                    name  \
# 93802  4iJyoBOLtHqaGxP12qzhQI  Peaches (feat. Daniel Caesar & Giveon)
# 93803  7lPN2DXiMsVn7XUKtOW1CS                         drivers license
# 93804  3Ofmpyhv5UAQ70mENzB277                  Astronaut In The Ocean
# 92811  6tDDoYIxWvMLTdKpjFkc1B                               telepatía
# 92810  5QO79kh1waicV47BqGRL3g                         Save Your Tears
# 93805  7MAibcTli4IisCtbHKrGMh                     Leave The Door Open
# 92813  0VjIjW4GlUZAMYd2vXMi3b                         Blinding Lights
# 92814  6f3Slt0GbA2bPZlz0aIFXN                            The Business
# 92816  3FAJ6O0NOHQV8Mc5Ri6ENp                  Heartbreak Anniversary
# 92819  1xK1Gg9SxG8fy2Ya373oqb                                 Bandido
#
#        popularity  duration_ms  explicit  \
# 93802         100       198082         1
# 93803          99       242014         1
# 93804          98       132780         0
# ...

# %%
#Artist present in the 10th row
df[['artists']].iloc[9]
# Out:
# artists    ['Ignacio Corsini']
# Name: 9, dtype: object

# %%
# Select only numeric columns (assuming all non-numeric columns should be excluded)
numeric_columns = df.select_dtypes(include=[np.number])

# Calculate the correlation matrix
corr_df = numeric_columns.corr(method='pearson')

# Display correlation
corr_df
# Out:
#                   popularity  duration_ms  explicit  danceability    energy  \
# popularity          1.000000     0.027681  0.211758      0.187000  0.302315
# duration_ms         0.027681     1.000000 -0.016747     -0.120371  0.024825
# explicit            0.211758    -0.016747  1.000000      0.150229  0.123076
# danceability        0.187000    -0.120371  0.150229      1.000000  0.241563
# energy              0.302315     0.024825  0.123076      0.241563  1.000000
# key                 0.015299     0.004626  0.010932      0.018824  0.036294
# loudness            0.327028     0.000337  0.134603      0.251436  0.764735
# mode               -0.033655    -0.027610 -0.051754     -0.044719 -0.065246
# speechiness        -0.047357    -0.125771  0.102258      0.199310 -0.053506
# acousticness       -0.370882    -0.064434 -0.149018     -0.242951 -0.715412
# instrumentalness   -0.236487     0.069278 -0.067520     -0.225900 -0.195839
# ...

# %%
plt.figure(figsize=(12, 6))
heatmap = sns.heatmap(corr_df, annot=True, fmt='.1g', vmin=-1, center=0, cmap='inferno', linewidths=1, linecolor='black')
heatmap.set_title("Correlation Heatmap Between Variables")
# Out:
# Text(0.5, 1.0, 'Correlation Heatmap Between Variables')

# %%
# Create a sample by taking .4% of the total data
sample_df = df.sample(int(0.04*len(df)))
print(len(sample_df))
# Out:
# 23466

# %%
sample_df.head(5)
# Out:
#                             id                        name  popularity  \
# 548443  49fcVrjOFtIWlkYrVRh9ls  とまどうペリカン - Remastered 2018          26
# 248916  65mfzTlRpqKQeDYOkkvWcw             Não Chora Neném          31
# 377843  4elEqrv2647JBpY9rB7fN4                       Sonia          34
# 449153  4ugtAcWEHYoumYCGpQRkDP             Selamanya Cinta          39
# 242620  6Qy2IIzTWeZOUgdPs6Umea                Take Me Baby          36
#
#         duration_ms  explicit            artists                  id_artists  \
# 548443       290373         0    ['Yosui Inoue']  ['4BQT8wAPy5SGtRnfstMzbA']
# 248916       192640         0  ['Beth Carvalho']  ['56TkPi7rpmU8jTpkcK7FY3']
# 377843       202507         0  ['Patrick Juvet']  ['7c5wlQVkajxJG0X13D0Fpc']
# 449153       308693         0     ['Yana Julio']  ['1P5ZkOEU00s2RZrKiFRhAj']
# 242620       218760         1     ['Jimi Tenor']  ['69H6uUTI29XBzQXV1d3A7D']
#
# ...

# %%
# Regression plot between loudness and Energy
plt.figure(figsize=(10,5))
sns.regplot(data = df, y='loudness', x='energy', color='c', fit_reg = True, line_kws = {'color':'blue'}).set(title='Loudness vs Energy Correlation')
# Out:
# [Text(0.5, 1.0, 'Loudness vs Energy Correlation')]

# %%
# Regression plot between Popularity and Acousticness
plt.figure(figsize=(10,5))
sns.regplot(data = sample_df, y='popularity', x='acousticness', color='g', fit_reg=True, line_kws={'color':'red'}).set(title='Popularity vs Acousticness Correlation')
# Out:
# [Text(0.5, 1.0, 'Popularity vs Acousticness Correlation')]

# %%
df.columns
# Out:
# Index(['id', 'name', 'popularity', 'duration_ms', 'explicit', 'artists',
#        'id_artists', 'release_date', 'danceability', 'energy', 'key',
#        'loudness', 'mode', 'speechiness', 'acousticness', 'instrumentalness',
#        'liveness', 'valence', 'tempo', 'time_signature'],
#       dtype='object')

# %%
df['release_date']
# Out:
# 0         1922-02-22
# 1         1922-06-01
# 2         1922-03-21
# 3         1922-03-21
# 4               1922
#              ...
# 586667    2020-09-26
# 586668    2020-10-21
# 586669    2020-09-02
# 586670    2021-03-05
# 586671    2015-07-01
# Name: release_date, Length: 586672, dtype: object

# %%
# Remove rows with invalid date values
df = df[df['release_date'].str.match(r'\d{4}-\d{2}-\d{2}')]

# %%
# Set the release date column as the index
df.set_index('release_date', inplace=True)
df.index = pd.to_datetime(df.index)

print(df)
# Out:
#                                   id                                 name  \
# release_date
# 1922-02-22    35iwgR4jXetI318WEWsa1Q                                Carve
# 1922-06-01    021ht4sdgPcrDgSk7JTbKY  Capítulo 2.16 - Banquero Anarquista
# 1922-03-21    07A5yehtSnoedViJAZkNnc   Vivo para Quererte - Remasterizado
# 1922-03-21    08FmqUhxtyLTn6pAh6bk45        El Prisionero - Remasterizado
# 1922-03-29    0JV4iqw2lSKJaHBQZ0e5zK        Martín Fierro - Remasterizado
# ...                              ...                                  ...
# 2020-09-26    5rgu12WBIHQtvej2MdHSH0                                  云与海
# 2020-10-21    0NuWgxEp51CutD2pJoF4OM                                blind
# 2020-09-02    27Y1N4Q4U3EfDU5Ubw8ws2            What They'll Say About Us
# 2021-03-05    45XJsGpFTyzbzeWK8VzR8S                      A Day At A Time
# 2015-07-01    5Ocn6dZ3BJFPWh4ylwFXtn                     Mar de Emociones
#
#               popularity  duration_ms  explicit  \
# release_date
# ...

# %%
df.index
# Out:
# DatetimeIndex(['1922-02-22', '1922-06-01', '1922-03-21', '1922-03-21',
#                '1922-03-29', '1922-06-01', '1922-06-01', '1922-02-22',
#                '1922-06-01', '1922-06-01',
#                ...
#                '2020-12-20', '2020-12-29', '2020-03-03', '2020-03-20',
#                '2020-02-08', '2020-09-26', '2020-10-21', '2020-09-02',
#                '2021-03-05', '2015-07-01'],
#               dtype='datetime64[ns]', name='release_date', length=448081, freq=None)

# %%
df.index.get_level_values('release_date')
# Out:
# DatetimeIndex(['1922-02-22', '1922-06-01', '1922-03-21', '1922-03-21',
#                '1922-03-29', '1922-06-01', '1922-06-01', '1922-02-22',
#                '1922-06-01', '1922-06-01',
#                ...
#                '2020-12-20', '2020-12-29', '2020-03-03', '2020-03-20',
#                '2020-02-08', '2020-09-26', '2020-10-21', '2020-09-02',
#                '2021-03-05', '2015-07-01'],
#               dtype='datetime64[ns]', name='release_date', length=448081, freq=None)

# %%
# Create a new column called years from release date column
df['dates'] = df.index.get_level_values('release_date')
df.dates = pd.to_datetime(df.dates)
years = df.dates.dt.year

years
# Out:
# release_date
# 1922-02-22    1922
# 1922-06-01    1922
# 1922-03-21    1922
# 1922-03-21    1922
# 1922-03-29    1922
#               ...
# 2020-09-26    2020
# 2020-10-21    2020
# 2020-09-02    2020
# 2021-03-05    2021
# 2015-07-01    2015
# Name: dates, Length: 448081, dtype: int32

# %%
# Distribution plot (bar plot) for total number of song per year
plt.figure(figsize=(10,6))
sns.displot(years, discrete=True, aspect=2, height=5, kind='hist').set_titles('Total numbers of songs per year')

# %%
# Convert duration in milliseconds to seconds
df['duration'] = df['duration_ms'].apply(lambda x: round(x/1000))
df.drop('duration_ms', inplace = True, axis = 1)

# %%
# Duration of the songs over the years
total_dr = df.duration

print(total_dr)
# Out:
# release_date
# 1922-02-22    127
# 1922-06-01     98
# 1922-03-21    182
# 1922-03-21    177
# 1922-03-29    181
#              ...
# 2020-09-26    258
# 2020-10-21    153
# 2020-09-02    188
# 2021-03-05    142
# 2015-07-01    214
# Name: duration, Length: 448081, dtype: int64

# %%
# Barplot for Year vs Duration
fig, ax = plt.subplots(figsize=(18, 8))
sns.barplot(x=years, y=total_dr, ax=ax)
ax.set(title='Year vs Duration')
plt.xticks(rotation=90)
ax.set_xlabel('Year')  # Add x-axis label
# Out:
# Text(0.5, 0, 'Year')

# %%
# Line plot for average duration of the songs over the years
total_dr = df.duration

print(total_dr)
# Out:
# release_date
# 1922-02-22    127
# 1922-06-01     98
# 1922-03-21    182
# 1922-03-21    177
# 1922-03-29    181
#              ...
# 2020-09-26    258
# 2020-10-21    153
# 2020-09-02    188
# 2021-03-05    142
# 2015-07-01    214
# Name: duration, Length: 448081, dtype: int64

# %%
plt.figure(figsize=(10, 5))
sns.lineplot(x=years, y=total_dr)
plt.title('Year vs Duration')
plt.xlabel('Year')
plt.show()

# %%
# Load Spotify Data
df_genre = pd.read_csv('Spotify.csv')
df_genre.head(5)
# Out:
#    genre        artist_name                        track_name  \
# 0  Movie     Henri Salvador       C'est beau de faire un Show
# 1  Movie  Martin & les fées  Perdu d'avance (par Gad Elmaleh)
# 2  Movie    Joseph Williams    Don't Let Me Be Lonely Tonight
# 3  Movie     Henri Salvador    Dis-moi Monsieur Gordon Cooper
# 4  Movie       Fabien Nataf                         Ouverture
#
#                  track_id  popularity  acousticness  danceability  \
# 0  0BRjO6ga9RKCKjfDqeFgWV           0         0.611         0.389
# 1  0BjC1NfoEOOusryehmNudP           1         0.246         0.590
# 2  0CoSDzoNIKCRs124s9uTVy           3         0.952         0.663
# 3  0Gc6TVm52BwZD07Ki6tIvf           0         0.703         0.240
# 4  0IuslXpMROHdEPvSl1fTQK           4         0.950         0.331
#
#    duration_ms  energy  instrumentalness key  liveness  loudness   mode  \
# 0        99373   0.910             0.000  C#    0.3460    -1.828  Major
# ...

# %%
df.columns
# Out:
# Index(['id', 'name', 'popularity', 'explicit', 'artists', 'id_artists',
#        'danceability', 'energy', 'key', 'loudness', 'mode', 'speechiness',
#        'acousticness', 'instrumentalness', 'liveness', 'valence', 'tempo',
#        'time_signature', 'dates', 'duration'],
#       dtype='object')

# %%
df.index
# Out:
# DatetimeIndex(['1922-02-22', '1922-06-01', '1922-03-21', '1922-03-21',
#                '1922-03-29', '1922-06-01', '1922-06-01', '1922-02-22',
#                '1922-06-01', '1922-06-01',
#                ...
#                '2020-12-20', '2020-12-29', '2020-03-03', '2020-03-20',
#                '2020-02-08', '2020-09-26', '2020-10-21', '2020-09-02',
#                '2021-03-05', '2015-07-01'],
#               dtype='datetime64[ns]', name='release_date', length=448081, freq=None)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 448081 entries, 1922-02-22 to 2015-07-01
# Data columns (total 20 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   id                448081 non-null  object
#  1   name              448010 non-null  object
#  2   popularity        448081 non-null  int64
#  3   explicit          448081 non-null  int64
#  4   artists           448081 non-null  object
#  5   id_artists        448081 non-null  object
#  6   danceability      448081 non-null  float64
#  7   energy            448081 non-null  float64
#  8   key               448081 non-null  int64
#  9   loudness          448081 non-null  float64
#  10  mode              448081 non-null  int64
#  11  speechiness       448081 non-null  float64
#  12  acousticness      448081 non-null  float64
#  13  instrumentalness  448081 non-null  float64
#  14  liveness          448081 non-null  float64
# ...

# %%
df.describe()
# Out:
#           popularity       explicit   danceability         energy  \
# count  448081.000000  448081.000000  448081.000000  448081.000000
# mean       29.603177       0.053024       0.572491       0.564269
# min         0.000000       0.000000       0.000000       0.000000
# 25%        15.000000       0.000000       0.464000       0.380000
# 50%        30.000000       0.000000       0.585000       0.576000
# 75%        43.000000       0.000000       0.691000       0.764000
# max       100.000000       1.000000       0.991000       1.000000
# std        18.570246       0.224081       0.162933       0.245024
#
#                  key       loudness           mode    speechiness  \
# count  448081.000000  448081.000000  448081.000000  448081.000000
# mean        5.238305      -9.692800       0.649347       0.102932
# min         0.000000     -60.000000       0.000000       0.000000
# 25%         2.000000     -12.204000       0.000000       0.033900
# ...

# %%
df.describe(include=object)
# Out:
#                             id       name           artists  \
# count                   448081     448010            448081
# unique                  448081     351049             96985
# top     5Ocn6dZ3BJFPWh4ylwFXtn  Year 3000  ['Die drei ???']
# freq                         1         88              3816
#
#                         id_artists
# count                       448081
# unique                       97814
# top     ['3meJIgRw7YleJrmbpbJK6S']
# freq                          3816

# %%
df.describe(include=int)
# Out:
#           popularity       explicit            key           mode  \
# count  448081.000000  448081.000000  448081.000000  448081.000000
# mean       29.603177       0.053024       5.238305       0.649347
# std        18.570246       0.224081       3.527436       0.477175
# min         0.000000       0.000000       0.000000       0.000000
# 25%        15.000000       0.000000       2.000000       0.000000
# 50%        30.000000       0.000000       5.000000       1.000000
# 75%        43.000000       0.000000       8.000000       1.000000
# max       100.000000       1.000000      11.000000       1.000000
#
#        time_signature       duration
# count   448081.000000  448081.000000
# mean         3.882809     230.117289
# std          0.455116     125.865986
# min          0.000000       5.000000
# 25%          4.000000     178.000000
# 50%          4.000000     217.000000
# 75%          4.000000     264.000000
# max          5.000000    5621.000000

# %%
df.describe(include=float)
# Out:
#         danceability         energy       loudness    speechiness  \
# count  448081.000000  448081.000000  448081.000000  448081.000000
# mean        0.572491       0.564269      -9.692800       0.102932
# std         0.162933       0.245024       4.802275       0.170433
# min         0.000000       0.000000     -60.000000       0.000000
# 25%         0.464000       0.380000     -12.204000       0.033900
# 50%         0.585000       0.576000      -8.771000       0.044800
# 75%         0.691000       0.764000      -6.224000       0.079200
# max         0.991000       1.000000       5.376000       0.969000
#
#         acousticness  instrumentalness       liveness        valence  \
# count  448081.000000     448081.000000  448081.000000  448081.000000
# mean        0.419365          0.100182       0.214538       0.555093
# std         0.341112          0.251499       0.185420       0.254527
# min         0.000000          0.000000       0.000000       0.000000
# ...

# %%
# Duration of the song for different genres
plt.figure(figsize=(10, 5))
sns.color_palette('rocket', as_cmap = True)
sns.barplot(y='genre', x='duration_ms', data=df_genre)
plt.title('Duration of the songs in different genres')
plt.xlabel("Duration in milli seconds")
plt.ylabel('Genres')
# Out:
# Text(0, 0.5, 'Genres')

# %%
# Top 5 genres by popularity
famous = df_genre.sort_values('popularity', ascending = False).head(10)
plt.figure(figsize = (10,5))
sns.set_style(style = 'darkgrid')
sns.barplot(y='genre', x='popularity', data= famous).set(title = "Top 5 genres by popularity")
# Out:
# [Text(0.5, 1.0, 'Top 5 genres by popularity')]
